// %%
%use kotlingrad

// %%
val x by SVar(DReal)
val y by SVar(DReal)
val z by SVar(DReal)

// %%
val t = (1 + x * 2 - 3 + y + z / y).d(y).d(x) + z / y * 3 - 2

// %%
HTML(t.html())
// Out:
// <svg width="881px" height="298px"
//  viewBox="0.00 0.00 881.00 298.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1.0 1.0) rotate(0) translate(4 294)">
// <title>%3</title>
// <!-- 667470429 -->
// <g id="node1" class="node">
// <title>667470429</title>
// <path fill="none" stroke="#000000" stroke-width="2" d="M831,-56.5C831,-56.5 861,-56.5 861,-56.5 867,-56.5 873,-62.5 873,-68.5 873,-68.5 873,-80.5 873,-80.5 873,-86.5 867,-92.5 861,-92.5 861,-92.5 831,-92.5 831,-92.5 825,-92.5 819,-86.5 819,-80.5 819,-80.5 819,-68.5 819,-68.5 819,-62.5 825,-56.5 831,-56.5"/>
// <text text-anchor="middle" x="846" y="-69.5" font-family="Lucida Console" font-size="20.00" fill="#000000">+</text>
// </g>
// <!-- 467802552 -->
// <g id="node2" class="node">
// <title>467802552</title>
// ...

// %%
val f = t + sin(y)

// %%
HTML(f.html())
// Out:
// <svg width="971px" height="358px"
//  viewBox="0.00 0.00 971.00 358.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1.0 1.0) rotate(0) translate(4 354)">
// <title>%3</title>
// <!-- 124798404 -->
// <g id="node1" class="node">
// <title>124798404</title>
// <path fill="none" stroke="#000000" stroke-width="2" d="M921,-23.5C921,-23.5 951,-23.5 951,-23.5 957,-23.5 963,-29.5 963,-35.5 963,-35.5 963,-47.5 963,-47.5 963,-53.5 957,-59.5 951,-59.5 951,-59.5 921,-59.5 921,-59.5 915,-59.5 909,-53.5 909,-47.5 909,-47.5 909,-35.5 909,-35.5 909,-29.5 915,-23.5 921,-23.5"/>
// <text text-anchor="middle" x="936" y="-36.5" font-family="Lucida Console" font-size="20.00" fill="#000000">+</text>
// </g>
// <!-- 667470429 -->
// <g id="node2" class="node">
// <title>667470429</title>
// ...

// %%
HTML(f(y to 1).html())
// Out:
// <svg width="1076px" height="320px"
//  viewBox="0.00 0.00 1076.00 320.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1.0 1.0) rotate(0) translate(4 316)">
// <title>%3</title>
// <!-- 91177510 -->
// <g id="node1" class="node">
// <title>91177510</title>
// <path fill="none" stroke="#000000" stroke-width="2" d="M1026,-57.5C1026,-57.5 1056,-57.5 1056,-57.5 1062,-57.5 1068,-63.5 1068,-69.5 1068,-69.5 1068,-81.5 1068,-81.5 1068,-87.5 1062,-93.5 1056,-93.5 1056,-93.5 1026,-93.5 1026,-93.5 1020,-93.5 1014,-87.5 1014,-81.5 1014,-81.5 1014,-69.5 1014,-69.5 1014,-63.5 1020,-57.5 1026,-57.5"/>
// <text text-anchor="middle" x="1041" y="-70.5" font-family="Lucida Console" font-size="20.00" fill="#000000">+</text>
// </g>
// <!-- 1756926561 -->
// <g id="node2" class="node">
// <title>1756926561</title>
// ...
