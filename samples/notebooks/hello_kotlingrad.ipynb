// %%
@file:DependsOn("ai.hypergraph:kotlingrad:0.4.6")

// %%
val x by SVar(DReal)
val y by SVar(DReal)
val z by SVar(DReal)

// %%
val t = (1 + x * 2 - 3 + y + z / y).d(y).d(x) + z / y * 3 - 2; t
// Out:
// <svg width="872px" height="286px"
//  viewBox="0.00 0.00 872.00 285.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1.0 1.0) rotate(0.0) translate(4.0 281.5)">
// <title>%3</title>
// <!-- 78f11 -->
// <g id="node1" class="node">
// <title>78f11</title>
// <path fill="none" stroke="#000000" stroke-width="4" d="M642,-180.5C642,-180.5 672,-180.5 672,-180.5 678,-180.5 684,-186.5 684,-192.5 684,-192.5 684,-204.5 684,-204.5 684,-210.5 678,-216.5 672,-216.5 672,-216.5 642,-216.5 642,-216.5 636,-216.5 630,-210.5 630,-204.5 630,-204.5 630,-192.5 630,-192.5 630,-186.5 636,-180.5 642,-180.5"/>
// <text text-anchor="middle" x="657" y="-193.5" font-family="Helvetica,sans-Serif" font-size="20.00" fill="#000000">d</text>
// </g>
// <!-- 1c100 -->
// <g id="node2" class="node">
// <title>1c100</title>
// ...
