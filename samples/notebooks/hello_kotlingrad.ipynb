// %%
%use kotlingrad

// %%
val x by SVar(DReal)
val y by SVar(DReal)
val z by SVar(DReal)

// %%
val t = (1 + x * 2 - 3 + y + z / y).d(y).d(x) + z / y * 3 - 2

// %%
HTML(t.html())
// Out:
// <svg width="872px" height="316px"
//  viewBox="0.00 0.00 872.00 315.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1.0 1.0) rotate(0) translate(4 311.5)">
// <title>%3</title>
// <!-- 94d9d -->
// <g id="node1" class="node">
// <title>94d9d</title>
// <path fill="none" stroke="black" stroke-width="4" d="M732,-132.5C732,-132.5 762,-132.5 762,-132.5 768,-132.5 774,-138.5 774,-144.5 774,-144.5 774,-156.5 774,-156.5 774,-162.5 768,-168.5 762,-168.5 762,-168.5 732,-168.5 732,-168.5 726,-168.5 720,-162.5 720,-156.5 720,-156.5 720,-144.5 720,-144.5 720,-138.5 726,-132.5 732,-132.5"/>
// <text text-anchor="middle" x="747" y="-144.5" font-family="Helvetica,sans-Serif" font-size="20.00">+</text>
// </g>
// <!-- 8e4b5 -->
// <g id="node2" class="node">
// <title>8e4b5</title>
// ...

// %%
val f = t + sin(y)

// %%
HTML(f.html())
// Out:
// <svg width="962px" height="372px"
//  viewBox="0.00 0.00 962.00 371.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1.0 1.0) rotate(0) translate(4 367.5)">
// <title>%3</title>
// <!-- 8d973 -->
// <g id="node1" class="node">
// <title>8d973</title>
// <path fill="none" stroke="black" stroke-width="4" d="M822,-65C822,-65 852,-65 852,-65 858,-65 864,-71 864,-77 864,-77 864,-89 864,-89 864,-95 858,-101 852,-101 852,-101 822,-101 822,-101 816,-101 810,-95 810,-89 810,-89 810,-77 810,-77 810,-71 816,-65 822,-65"/>
// <text text-anchor="middle" x="837" y="-77" font-family="Helvetica,sans-Serif" font-size="20.00">+</text>
// </g>
// <!-- 2ca4c -->
// <g id="node2" class="node">
// <title>2ca4c</title>
// ...

// %%
HTML(f(y to 1).html())
// Out:
// <svg width="1032px" height="311px"
//  viewBox="0.00 0.00 1031.77 310.85" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1.0 1.0) rotate(0) translate(4 306.85)">
// <title>%3</title>
// <!-- 0f438 -->
// <g id="node1" class="node">
// <title>0f438</title>
// <path fill="none" stroke="black" stroke-width="4" d="M813.45,-75.5C813.45,-75.5 843.45,-75.5 843.45,-75.5 849.45,-75.5 855.45,-81.5 855.45,-87.5 855.45,-87.5 855.45,-99.5 855.45,-99.5 855.45,-105.5 849.45,-111.5 843.45,-111.5 843.45,-111.5 813.45,-111.5 813.45,-111.5 807.45,-111.5 801.45,-105.5 801.45,-99.5 801.45,-99.5 801.45,-87.5 801.45,-87.5 801.45,-81.5 807.45,-75.5 813.45,-75.5"/>
// <text text-anchor="middle" x="828.45" y="-87.5" font-family="Helvetica,sans-Serif" font-size="20.00">+</text>
// </g>
// <!-- 9e887 -->
// <g id="node2" class="node">
// <title>9e887</title>
// ...
