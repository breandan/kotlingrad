// %%
%use kotlingrad
// Out:
// :: problems summary ::
// :::: WARNINGS
// 		module not found: ch.obermuhlner#big-math;_
//
// 	==== jcenter.bintray.com: tried
//
// 	  https://jcenter.bintray.com/ch/obermuhlner/big-math/_/big-math-_.pom
//
// 	  -- artifact ch.obermuhlner#big-math;_!big-math.jar:
//
// 	  https://jcenter.bintray.com/ch/obermuhlner/big-math/_/big-math-_.jar
//
// 	==== repo.maven.apache.org: tried
//
// 	  https://repo.maven.apache.org/maven2/ch/obermuhlner/big-math/_/big-math-_.pom
//
// 	  -- artifact ch.obermuhlner#big-math;_!big-math.jar:
//
// 	  https://repo.maven.apache.org/maven2/ch/obermuhlner/big-math/_/big-math-_.jar
//
// 	==== jitpack.io: tried
//
// 	  https://jitpack.io/ch/obermuhlner/big-math/_/big-math-_.pom
//
// 	  -- artifact ch.obermuhlner#big-math;_!big-math.jar:
//
// 	  https://jitpack.io/ch/obermuhlner/big-math/_/big-math-_.jar
//
// 	==== jitpack.io: tried
//
// 	  https://jitpack.io/ch/obermuhlner/big-math/_/big-math-_.pom
//
// ...

// %%
val x by SVar(DReal)
val y by SVar(DReal)
val z by SVar(DReal)
// Out:
// Line_1.jupyter.kts (1:10 - 14) Unresolved reference: SVar
// Line_1.jupyter.kts (1:15 - 20) Unresolved reference: DReal
// Line_1.jupyter.kts (2:10 - 14) Unresolved reference: SVar
// Line_1.jupyter.kts (2:15 - 20) Unresolved reference: DReal
// Line_1.jupyter.kts (3:10 - 14) Unresolved reference: SVar
// Line_1.jupyter.kts (3:15 - 20) Unresolved reference: DReal

// %%
val t = (1 + x * 2 - 3 + y + z / y).d(y).d(x) + z / y * 3 - 2

// %%
t
